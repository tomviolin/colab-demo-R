# %% [markdown]
# <a href="https://colab.research.google.com/github/tomviolin/colab-demo-R/blob/main/demo-R-notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=seq(0,2*pi,0.01*pi)
plot(x, sin(x), type='l')
# Out:
# plot without title

# %%
install.packages("rjson")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library("rjson")

# %%
toJSON(c(1,2,3,4))
# Out:
# [1] "[1,2,3,4]"
